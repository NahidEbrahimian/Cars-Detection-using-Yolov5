# %%
# !pip install wandb

# %%
import wandb
# import tensorflow as tf

# %%
cd /content/drive/MyDrive/Yolov5ObjectDetection
# Out:
# /content/drive/MyDrive/Yolov5ObjectDetection

# %%
# !git clone https://github.com/ultralytics/yolov5.git

# %%
wandb.init(project='yolov5objectdetection', entity='nahid-ebrahimian')
# Out:
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit: ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
#                     Syncing run <strong><a href="https://wandb.ai/nahid-ebrahimian/yolov5objectdetection/runs/10wckdur" target="_blank">eternal-pine-30</a></strong> to <a href="https://wandb.ai/nahid-ebrahimian/yolov5objectdetection" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src="https://wandb.ai/nahid-ebrahimian/yolov5objectdetection/runs/10wckdur?jupyter=true" style="border:none;width:100%;height:420px;display:none;"></iframe>

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# !pip install -U -r yolov5/requirements.txt  # install dependencies

# %%
# !cd /content/drive/MyDrive/YoloObjectDetection/yolov5/train.py
# !python yolov5/train.py --img 640 --batch 8 --epochs 30 --data coco128.yaml --weights yolov5s.pt
# Out:
# ...
# wandb: Currently logged in as: nahid-ebrahimian (use `wandb login --relogin` to force relogin)
# train: weights=yolov5s.pt, cfg=, data=coco128.yaml, hyp=yolov5/data/hyps/hyp.scratch.yaml, epochs=30, batch_size=8, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5/runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 2022-1-12 torch 1.10.1+cu102 CUDA:0 (Tesla K80, 11441MiB)
#
# ...

# %%
# !python yolov5/train.py --img 640 --batch 8 --epochs 30 --data coco128.yaml --weights yolov5s.pt
# Out:
# train: weights=yolov5s.pt, cfg=, data=coco128.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=30, batch_size=8, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, entity=None, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias=latest, local_rank=-1, freeze=0, patience=30
# fatal: could not read Username for 'https://github.com': No such device or address
# github: Command 'git fetch && git config --get remote.origin.url' returned non-zero exit status 128.
# ...

# %% [markdown]
# https://github.com/ultralytics/yolov5/wiki/Train-Custom-Data

# %% [markdown]
# ### inference

# %%
# !python /content/drive/MyDrive/YoloObjectDetection/yolov5/detect.py --weights /content/drive/MyDrive/YoloObjectDetection/runs/train/exp13/weights/last.pt --img 224 --conf 0.4 --source /content/drive/MyDrive/YoloObjectDetection/data/saipa_saina88.jpg
# Out:
# detect: weights=['/content/drive/MyDrive/YoloObjectDetection/runs/train/exp13/weights/last.pt'], source=/content/drive/MyDrive/YoloObjectDetection/data/saipa_saina88.jpg, imgsz=[224, 224], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False
# requirements: /content/drive/MyDrive/YoloObjectDetection/requirements.txt not found, check failed.
# YOLOv5 🚀 v5.0-387-g7b35971 torch 1.9.0+cu102 CUDA:0 (Tesla K80, 11441.1875MB)
#
# Fusing layers...
# Model Summary: 224 layers, 7064698 parameters, 0 gradients
# image 1/1 /content/drive/MyDrive/YoloObjectDetection/data/saipa_saina88.jpg: 192x224 1 saipa_saina, Done. (0.014s)
# Results saved to runs/detect/exp11
# Done. (0.254s)

# %% [markdown]
# ### clone from my github

# %%
# !pip install -U -r yolov5/requirements.txt  # install dependencies
